# %% [markdown]
# # Adult income - Decision Tree
# Project Objectives | Problem Statements
# 1.1. PO1 | PS1: Segmentation of Adult income Data using Supervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Determination of an Appropriate Classification Model
#
# 1.3. PO3 | PS3: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification
#
#
# Description of Data
# 2.1. Data Source, Size, Shape
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/wenruliu/adult-income-dataset/download?datasetVersionNumber=2)
#
# 2.1.2. Data Size (670 Kb)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-11 | Number of Records-48842 rows × 11 columns) 2.2. Description of Variables
#
# 2.2.1. Index Variable(s)
#
# Index Variable(s): S.No.
#
# 2.2. Variables or Features having Categories | Categorical Variables or Features (CV)
#
# 2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type
#
# Nominal Categories:
#
# 1.Marital Status
#
# 2.Occupation
#
# 3.Relationship
#
# 4.Race
#
# 5.Gender
#
# 6.Native country
#
# 7.Income
#
# 2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type
#
# Ordinal Categories:
#
# 1.Education
#
# 2.Educational num
#
# 2.2.3. Non-Categorical Variables or Features Non-Categorical Variables or Features:
#
# Age
#
# Capital gain
#
# Capital loss
#
# Hours per week
#
# Variable Description:
#
# Index Variable: S.no.: A sequential identifier for each record.
#
# workclass: The type of work class of the individual (e.g., Private, Self-emp-inc, Federal-gov).
#
# marital status: The marital status of the individual (e.g., Married-civ-spouse, Divorced, Never-married).
#
# occupation: The occupation of the individual (e.g., Exec-managerial, Handlers-cleaners, Prof-specialty).
#
# relationship: The relationship status of the individual (e.g., Husband, Wife, Own-child).
#
# race: The race of the individual (e.g., White, Black, Asian-Pac-Islander).
#
# gender: The gender of the individual (e.g., Male, Female).
#
# education: The highest level of education achieved by the individual (e.g., Bachelors, HS-grad, Masters).
#
# educational num: A numerical representation of the education level, where higher numbers indicate higher education.
#
# native country: The native country of the individual (e.g., United-States, Mexico, Philippines).
#
# income: The income level of the individual, categorized as <=50K or >50K.
#
#
# ### Descriptive Statistics: Outcome Variable or Feature (Categorical)
# #### 2.3.1.1. Count | Frequency Statistics
# - `income`:
#   - <=50K: 37155 (76.07%)
#   - >50K: 11687 (23.93%)
#
# #### 2.3.1.2. Proportion (Relative Frequency) Statistics
# - `income`:
#   - <=50K: 76.07%
#   - >50K: 23.93%
#
# ### Descriptive Statistics: Input Categorical Variables or Features
# #### 2.3.2.1. Count | Frequency Statistics
# - `workclass`:
#   - Private: 33906 (69.49%)
#   - Self-emp-not-inc: 3862 (7.91%)
#   - Local-gov: 3136 (6.
#
# You seem to have stopped abruptly while providing the counts for different categories within the `workclass` variable. Here's the continuation and completion of that section:
#
# - `workclass` (continued):
#   - Private: 33906 (69.49%)
#   - Self-emp-not-inc: 3862 (7.91%)
#   - Local-gov: 3136 (6.42%)
#   - State-gov: 1981 (4.06%)
#   - Self-emp-inc: 1695 (3.47%)
#   - Federal-gov: 1432 (2.93%)
#   - Without-pay: 21 (0.04%)
#   - Never-worked: 10 (0.02%)
#
# - `education`:
#   - HS-grad: 15784 (32.32%)
#   - Some-college: 10878 (22.30%)
#   - Bachelors: 8025 (16.43%)
#   - Masters: 2657 (5.44%)
#   - Assoc-voc: 2061 (4.22%)
#   - 11th: 1812 (3.71%)
#   - Assoc-acdm: 1601 (3.28%)
#   - 10th: 1389 (2.84%)
#   - 7th-8th: 955 (1.95%)
#   - Prof-school: 834 (1.71%)
#   - 9th: 756 (1.55%)
#   - 12th: 657 (1.34%)
#   - Doctorate: 594 (1.22%)
#   - 5th-6th: 509 (1.04%)
#   - 1st-4th: 247 (0.51%)
#
# #### 2.3.2.2. Proportion (Relative Frequency) Statistics
# - `workclass`:
#   - Private: 69.49%
#   - Self-emp-not-inc: 7.91%
#   - Local-gov: 6.42%
#   - State-gov: 4.06%
#   - Self-emp-inc: 3.47%
#   - Federal-gov: 2.93%
#   - Without-pay: 0.04%
#   - Never-worked: 0.02%
#
# - `education`:
#   - HS-grad: 32.32%
#   - Some-college: 22.30%
#   - Bachelors: 16.43%
#   - Masters: 5.44%
#   - Assoc-voc: 4.22%
#   - 11th: 3.71%
#   - Assoc-acdm: 3.28%
#   - 10th: 2.84%
#   - 7th-8th: 1.95%
#   - Prof-school: 1.71%
#   - 9th: 1.55%
#   - 12th: 1.34%
#   - Doctorate: 1.22%
#   - 5th-6th: 1.04%
#   - 1st-4th: 0.51%
#
# ### Descriptive Statistics: Input Non-Categorical Variables or Features
# #### 2.3.3.1. Measures of Central Tendency
# - `age`:
#   - Mean: 38.64
#   - Median: 37.00
#
# - `educational num`:
#   - Mean: 10.08
#   - Median: 10.00
#
# - `capital gain`:
#   - Mean: 1079.07
#   - Median: 0.00
#
# - `capital loss`:
#   - Mean: 87.50
#   - Median: 0.00
#
# - `hours per week`:
#   - Mean: 40.42
#   - Median: 40.00
#
# #### 2.3.3.2. Measures of Dispersion
# - `age`: Std Dev: 13.71
# - `educational num`: Std Dev: 2.57
# - `capital gain`: Std Dev: 7452.02
# - `capital loss`: Std Dev: 403.00
# - `hours per week`: Std Dev: 12.39
#
# Here's a structured report based on the information provided for data pre-processing:
#
# ### Data Pre-Processing
# #### 3.1. Missing Data Statistics and Treatment
# ##### 3.1.1.1. Missing Data Statistics: Records
# - No records have missing data.
#
# ##### 3.1.1.2. Missing Data Statistics: Categorical Variables or Features
# - No categorical variables have missing data.
#
# ##### 3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features
# - No non-categorical variables have missing data.
#
# ##### 3.1.1.4. Missing Data Treatment: Records
# - No records were removed due to missing data.
#
# ##### 3.1.1.5. Missing Data Treatment: Categorical Variables or Features
# - No categorical variables were removed or imputed due to missing data.
#
# ##### 3.1.1.6. Missing Data Treatment: Non-Categorical Variables or Features
# - No non-categorical variables were removed or imputed due to missing data.
#
# #### 3.1.2. Numerical Encoding of Categorical Variables or Features
# - Categorical variables were numerically encoded using the OrdinalEncoder in alphabetical order.
#
# #### 3.1.3. Outlier Statistics and Treatment
# - Outliers were not specifically addressed in this report.
#
# #### 3.1.4. Data Bifurcation: Training & Testing Sets
# - No data bifurcation was performed in this report.
#
# ### Final Pre-Processed Dataset
# - The final pre-processed dataset consists of 48842 records and 29 columns, including the original features and the newly added encoded and normalized features.
#
# ### 3.2. Data Analysis
#
# #### 3.2.1.1. Decision Tree (Base Model) | Metrics Used - Gini Coefficient, Entropy
# #### 3.2.1.2. Logistic Regression, Support Vector Machine, K Nearest Neighbour (Comparison Models) | Metrics Used
#
# #### 3.2.2.1.1. Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Base Model: Decision Tree)
# #### 3.2.2.1.2. Time Statistics | Memory Statistics (Base Model: Decision Tree)
# #### 3.2.2.2.1. Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Comparison Models: Logistic Regression, Support Vector Machine, K Nearest Neighbour)
# #### 3.2.2.2.2. Time Statistics | Memory Statistics (Comparison Models: Logistic Regression, Support Vector Machine, K Nearest Neighbour)
#
# #### 3.2.3.1. Variable or Feature Analysis: Base Model (Decision Tree)
# #### 3.2.3.1.1. Relevant or Important Variables or Features and their Thresholds
# #### 3.2.3.1.2. Non-Relevant or Non-Important Variables or Features
# #### 3.2.3.2. Variable or Feature Analysis: Comparison Models (Logistic Regression, Support Vector Machine, K Nearest Neighbour)
# #### 3.2.3.2.1. Relevant or Important Variables or Features and their Thresholds
# #### 3.2.3.2.2. Non-Relevant or Non-Important Variables or Features
#
# ### 4. Results | Observations
#
# #### 4.1. Classification Model Parameters: Base Model (Decision Tree) | Comparison Models (Logistic Regression, Support Vector Machine, K Nearest Neighbour)
# #### 4.2. Classification Model Performance: Time & Memory Statistics [Base Model (Decision Tree) | Comparison Models (Logistic Regression, Support Vector Machine, K Nearest Neighbour)]
# #### 4.3. Variable or Feature Analysis: Base Model (Decision Tree) | Comparison Models (Logistic Regression, Support Vector Machine, K Nearest Neighbour)
# #### 4.3.1. Relevant or Important Variables or Features and their Thresholds
# #### 4.3.2. Non-Relevant or Non-Important Variables or Features
#
# ### 5. Managerial Insights
#
# #### 5.1. Appropriate Model: Compare and Contrast {Decision Tree, Logistic Regression, Support Vector Machine, K Nearest Neighbour}
#
# - **Decision Tree:**
#   - *Strengths*: Easy to interpret and visualize, can handle both numerical and categorical data, requires little data preprocessing.
#   - *Weaknesses*: Prone to overfitting, especially with complex trees, not suitable for large datasets.
# - **Logistic Regression:**
#   - *Strengths*: Simple and fast, provides probabilities for outcomes, can handle large datasets well.
#   - *Weaknesses*: Assumes a linear relationship between features and outcome, may not perform well with non-linear relationships.
# - **Support Vector Machine (SVM):**
#   - *Strengths*: Effective in high-dimensional spaces, works well with small datasets, versatile with different kernel functions.
#   - *Weaknesses*: Memory-intensive, sensitive to the choice of kernel parameters, doesn't provide probability estimates directly.
# - **K Nearest Neighbour (KNN):**
#   - *Strengths*: Simple and intuitive, no training phase, can handle multi-class cases.
#   - *Weaknesses*: Computationally expensive, sensitive to the choice of k value, requires careful preprocessing of data.
#
# #### 5.2. Relevant or Important Variables or Features (Given the Appropriate Model)
#
# Based on the analysis, the relevant or important variables or features for the appropriate model can be determined. For example, for a Decision Tree model, the important features might include 'age', 'education', 'occupation', and 'native country' in predicting income levels. These features can be used by the organization to focus their marketing efforts, tailor their product offerings, or optimize their pricing strategies to target specific customer segments effectively.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("proj_2.csv")
df
# Out:
#        Unnamed: 0  S.no.  age     workclass     education  educational num  \
# 0               0      1   25       Private          11th                7
# 1               1      2   38       Private       HS-grad                9
# 2               2      3   28     Local-gov    Assoc-acdm               12
# 3               3      4   44       Private  Some-college               10
# 4               4      5   18       Private  Some-college               10
# ...           ...    ...  ...           ...           ...              ...
# 48837       48837  48838   27       Private    Assoc-acdm               12
# 48838       48838  48839   40       Private       HS-grad                9
# 48839       48839  48840   58       Private       HS-grad                9
# 48840       48840  48841   22       Private       HS-grad                9
# 48841       48841  48842   52  Self-emp-inc       HS-grad                9
#
#            marital status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married     Prof-specialty    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital gain  capital loss  hours per week native country income  \
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
#        cluster
# 0            0
# 1            0
# 2            0
# 3            3
# 4            0
# ...        ...
# 48837        0
# 48838        0
# 48839        0
# 48840        0
# 48841        2
#
# [48842 rows x 17 columns]

# %%
df_cat = df[['workclass', 'marital status','occupation','relationship','race','gender','education','educational num','native country','income']]
df_noncat = df[[ 'age','capital gain','capital loss','hours per week']]

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       48842 non-null  int64
#  1   S.no.            48842 non-null  int64
#  2   age              48842 non-null  int64
#  3   workclass        48842 non-null  object
#  4   education        48842 non-null  object
#  5   educational num  48842 non-null  int64
#  6   marital status   48842 non-null  object
#  7   occupation       48842 non-null  object
#  8   relationship     48842 non-null  object
#  9   race             48842 non-null  object
#  10  gender           48842 non-null  object
#  11  capital gain     48842 non-null  int64
#  12  capital loss     48842 non-null  int64
#  13  hours per week   48842 non-null  int64
#  14  native country   48842 non-null  object
#  15  income           48842 non-null  object
#  16  cluster          48842 non-null  int64
# dtypes: int64(8), object(9)
# memory usage: 6.3+ MB
# None
#          Unnamed: 0         S.no.           age  educational num  \
# count  48842.000000  48842.000000  48842.000000     48842.000000
# mean   24420.500000  24421.500000     38.643585        10.078089
# std    14099.615261  14099.615261     13.710510         2.570973
# min        0.000000      1.000000     17.000000         1.000000
# 25%    12210.250000  12211.250000     28.000000         9.000000
# 50%    24420.500000  24421.500000     37.000000        10.000000
# 75%    36630.750000  36631.750000     48.000000        12.000000
# max    48841.000000  48842.000000     90.000000        16.000000
#
#        capital gain  capital loss  hours per week       cluster
# count  48842.000000  48842.000000    48842.000000  48842.000000
# mean    1079.067626     87.502314       40.422382      0.178617
# std     7452.019058    403.004552       12.391444      0.679151
# min        0.000000      0.000000        1.000000      0.000000
# 25%        0.000000      0.000000       40.000000      0.000000
# 50%        0.000000      0.000000       40.000000      0.000000
# 75%        0.000000      0.000000       45.000000      0.000000
# max    99999.000000   4356.000000       99.000000      3.000000
# Unnamed: 0         0
# S.no.              0
# age                0
# workclass          0
# education          0
# educational num    0
# marital status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital gain       0
# capital loss       0
# hours per week     0
# native country     0
# income             0
# cluster            0
# dtype: int64
# 0        0
# 32564    0
# 32555    0
# 32556    0
# 32557    0
# dtype: int64

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)


# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   workclass        48842 non-null  object
#  1   marital status   48842 non-null  object
#  2   occupation       48842 non-null  object
#  3   relationship     48842 non-null  object
#  4   race             48842 non-null  object
#  5   gender           48842 non-null  object
#  6   education        48842 non-null  object
#  7   educational num  48842 non-null  object
#  8   native country   48842 non-null  object
#  9   income           48842 non-null  object
# dtypes: object(10)
# memory usage: 3.7+ MB

# %%
# 1.2.2.1. Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency
# --------------------------------------------------------------------------------------------

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  float64
#  1   capital gain    48842 non-null  float64
#  2   capital loss    48842 non-null  float64
#  3   hours per week  48842 non-null  float64
# dtypes: float64(4)
# memory usage: 1.5 MB

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat_mdi.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['workclass', 'marital status','occupation','relationship','race','gender','education','educational num','native country','income'])
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#         workclass_x    marital status_x       occupation_x relationship_x  \
# 0           Private       Never-married  Machine-op-inspct      Own-child
# 1           Private  Married-civ-spouse    Farming-fishing        Husband
# 2         Local-gov  Married-civ-spouse    Protective-serv        Husband
# 3           Private  Married-civ-spouse  Machine-op-inspct        Husband
# 4           Private       Never-married     Prof-specialty      Own-child
# ...             ...                 ...                ...            ...
# 48837       Private  Married-civ-spouse       Tech-support           Wife
# 48838       Private  Married-civ-spouse  Machine-op-inspct        Husband
# 48839       Private             Widowed       Adm-clerical      Unmarried
# 48840       Private       Never-married       Adm-clerical      Own-child
# 48841  Self-emp-inc  Married-civ-spouse    Exec-managerial           Wife
#
#       race_x gender_x   education_x educational num_x native country_x  \
# 0      Black     Male          11th                 7    United-States
# 1      White     Male       HS-grad                 9    United-States
# 2      White     Male    Assoc-acdm                12    United-States
# 3      Black     Male  Some-college                10    United-States
# 4      White   Female  Some-college                10    United-States
# ...      ...      ...           ...               ...              ...
# 48837  White   Female    Assoc-acdm                12    United-States
# 48838  White     Male       HS-grad                 9    United-States
# 48839  White   Female       HS-grad                 9    United-States
# 48840  White     Male       HS-grad                 9    United-States
# 48841  White   Female       HS-grad                 9    United-States
#
#       income_x  workclass_y  marital status_y  occupation_y  relationship_y  \
# 0        <=50K          3.0               4.0           6.0             3.0
# 1        <=50K          3.0               2.0           4.0             0.0
# 2         >50K          1.0               2.0          10.0             0.0
# 3         >50K          3.0               2.0           6.0             0.0
# 4        <=50K          3.0               4.0           9.0             3.0
# ...        ...          ...               ...           ...             ...
# 48837    <=50K          3.0               2.0          12.0             5.0
# 48838     >50K          3.0               2.0           6.0             0.0
# 48839    <=50K          3.0               6.0           0.0             4.0
# 48840    <=50K          3.0               4.0           0.0             3.0
# 48841     >50K          4.0               2.0           3.0             5.0
#
#        race_y  gender_y  education_y  educational num_y  native country_y  \
# 0         2.0       1.0          1.0                6.0              38.0
# 1         4.0       1.0         11.0                8.0              38.0
# 2         4.0       1.0          7.0               11.0              38.0
# 3         2.0       1.0         15.0                9.0              38.0
# 4         4.0       0.0         15.0                9.0              38.0
# ...       ...       ...          ...                ...               ...
# 48837     4.0       0.0          7.0               11.0              38.0
# 48838     4.0       1.0         11.0                8.0              38.0
# 48839     4.0       0.0         11.0                8.0              38.0
# 48840     4.0       1.0         11.0                8.0              38.0
# 48841     4.0       0.0         11.0                8.0              38.0
#
#        income_y
# 0           0.0
# 1           0.0
# 2           1.0
# 3           1.0
# 4           0.0
# ...         ...
# 48837       0.0
# 48838       1.0
# 48839       0.0
# 48840       0.0
# 48841       1.0
#
# [48842 rows x 20 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame
df_noncat = df[['age','capital gain','capital loss','hours per week']] # Non-Categorical Data

# Create vertical boxplot for 'total_cases'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['age'])
plt.title('Boxplot of age')
plt.ylabel('age')
plt.show()

# Create vertical boxplot for 'new_cases'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['capital gain'])
plt.title('Boxplot of capital gain')
plt.ylabel('capital gain')
plt.show()

# Create vertical boxplot for 'new_cases_smoothed'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['capital loss'])
plt.title('Boxplot of capital loss')
plt.ylabel('capital loss')
plt.show()

# Create vertical boxplot for 'total_deaths'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['hours per week'])
plt.title('Boxplot of hours per week')
plt.ylabel('hours per week')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si [['age','capital gain','capital loss','hours per week']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['age_mmnorm', 'capital gain_mmnorm', 'capital loss_mmnorm', 'hours per week_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
#df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
df_noncat_mdt_mmn = pd.merge(df_noncat_mdi_si, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#         age  capital gain  capital loss  hours per week  age_mmnorm  \
# 0      25.0           0.0           0.0            40.0    0.109589
# 1      38.0           0.0           0.0            50.0    0.287671
# 2      28.0           0.0           0.0            40.0    0.150685
# 3      44.0        7688.0           0.0            40.0    0.369863
# 4      18.0           0.0           0.0            30.0    0.013699
# ...     ...           ...           ...             ...         ...
# 48837  27.0           0.0           0.0            38.0    0.136986
# 48838  40.0           0.0           0.0            40.0    0.315068
# 48839  58.0           0.0           0.0            40.0    0.561644
# 48840  22.0           0.0           0.0            20.0    0.068493
# 48841  52.0       15024.0           0.0            40.0    0.479452
#
#        capital gain_mmnorm  capital loss_mmnorm  hours per week_mmnorm
# 0                 0.000000                  0.0               0.397959
# 1                 0.000000                  0.0               0.500000
# 2                 0.000000                  0.0               0.397959
# 3                 0.076881                  0.0               0.397959
# 4                 0.000000                  0.0               0.295918
# ...                    ...                  ...                    ...
# 48837             0.000000                  0.0               0.377551
# 48838             0.000000                  0.0               0.397959
# 48839             0.000000                  0.0               0.397959
# 48840             0.000000                  0.0               0.193878
# 48841             0.150242                  0.0               0.397959
#
# [48842 rows x 8 columns]

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
#         workclass_x    marital status_x       occupation_x relationship_x  \
# 0           Private       Never-married  Machine-op-inspct      Own-child
# 1           Private  Married-civ-spouse    Farming-fishing        Husband
# 2         Local-gov  Married-civ-spouse    Protective-serv        Husband
# 3           Private  Married-civ-spouse  Machine-op-inspct        Husband
# 4           Private       Never-married     Prof-specialty      Own-child
# ...             ...                 ...                ...            ...
# 48837       Private  Married-civ-spouse       Tech-support           Wife
# 48838       Private  Married-civ-spouse  Machine-op-inspct        Husband
# 48839       Private             Widowed       Adm-clerical      Unmarried
# 48840       Private       Never-married       Adm-clerical      Own-child
# 48841  Self-emp-inc  Married-civ-spouse    Exec-managerial           Wife
#
#       race_x gender_x   education_x educational num_x native country_x  \
# 0      Black     Male          11th                 7    United-States
# 1      White     Male       HS-grad                 9    United-States
# 2      White     Male    Assoc-acdm                12    United-States
# 3      Black     Male  Some-college                10    United-States
# 4      White   Female  Some-college                10    United-States
# ...      ...      ...           ...               ...              ...
# 48837  White   Female    Assoc-acdm                12    United-States
# 48838  White     Male       HS-grad                 9    United-States
# 48839  White   Female       HS-grad                 9    United-States
# 48840  White     Male       HS-grad                 9    United-States
# 48841  White   Female       HS-grad                 9    United-States
#
#       income_x  ...  income_y   age  capital gain  capital loss  \
# 0        <=50K  ...       0.0  25.0           0.0           0.0
# 1        <=50K  ...       0.0  38.0           0.0           0.0
# 2         >50K  ...       1.0  28.0           0.0           0.0
# 3         >50K  ...       1.0  44.0        7688.0           0.0
# 4        <=50K  ...       0.0  18.0           0.0           0.0
# ...        ...  ...       ...   ...           ...           ...
# 48837    <=50K  ...       0.0  27.0           0.0           0.0
# 48838     >50K  ...       1.0  40.0           0.0           0.0
# 48839    <=50K  ...       0.0  58.0           0.0           0.0
# 48840    <=50K  ...       0.0  22.0           0.0           0.0
# 48841     >50K  ...       1.0  52.0       15024.0           0.0
#
#        hours per week  age_mmnorm  capital gain_mmnorm  capital loss_mmnorm  \
# 0                40.0    0.109589             0.000000                  0.0
# 1                50.0    0.287671             0.000000                  0.0
# 2                40.0    0.150685             0.000000                  0.0
# 3                40.0    0.369863             0.076881                  0.0
# 4                30.0    0.013699             0.000000                  0.0
# ...               ...         ...                  ...                  ...
# 48837            38.0    0.136986             0.000000                  0.0
# 48838            40.0    0.315068             0.000000                  0.0
# 48839            40.0    0.561644             0.000000                  0.0
# 48840            20.0    0.068493             0.000000                  0.0
# 48841            40.0    0.479452             0.150242                  0.0
#
#        hours per week_mmnorm  cluster
# 0                   0.397959        0
# 1                   0.500000        0
# 2                   0.397959        0
# 3                   0.397959        3
# 4                   0.295918        0
# ...                      ...      ...
# 48837               0.377551        0
# 48838               0.397959        0
# 48839               0.397959        0
# 48840               0.193878        0
# 48841               0.397959        2
#
# [48842 rows x 29 columns]

# %%
final_new_df=final_df[['workclass_y', 'marital status_y', 'occupation_y', 'relationship_y' , 'race_y', 'gender_y', 'education_y', 'educational num_y', 'native country_y', 'income_y', 'age_mmnorm', 'capital gain_mmnorm', 'capital loss_mmnorm', 'hours per week_mmnorm', 'cluster']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
covid_inputs = final_df[['workclass_y', 'marital status_y', 'occupation_y', 'relationship_y' , 'race_y', 'gender_y', 'education_y', 'educational num_y', 'native country_y', 'income_y', 'age_mmnorm', 'capital gain_mmnorm', 'capital loss_mmnorm', 'hours per week_mmnorm']]; covid_inputs
covid_output = final_df[['cluster']]; covid_output

covid_inputs_names = covid_inputs.columns; covid_inputs_names
covid_output_labels = covid_output['cluster'].unique().astype(str); covid_output_labels

# Split the mtcars Data Subset into Training & Testing Sets
train_covid_inputs, test_covid_inputs, train_covid_output, test_covid_output = train_test_split(covid_inputs, covid_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45011)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(covid_inputs, covid_output):
    covid_inputs_train, covid_inputs_test = covid_inputs.iloc[train_index], covid_inputs.iloc[test_index]
    covid_output_train, covid_output_test = covid_output.iloc[train_index], covid_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45038)

# Fit the model on the training data
logreg_l1.fit(covid_inputs_train, covid_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
covid_inputs_train_selected = selector.transform(covid_inputs_train)
covid_inputs_test_selected = selector.transform(covid_inputs_test)

# Get the selected features
selected_features = covid_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['capital gain_mmnorm'], dtype='object')
# Threshold: 56.79884115221885
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45038,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(covid_inputs_train, covid_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45038)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(covid_inputs_names)); print(dtc_model_rules)
# Out:
# |--- capital gain_mmnorm <= 0.03
# |   |--- class: 0
# |--- capital gain_mmnorm >  0.03
# |   |--- capital gain_mmnorm <= 0.11
# |   |   |--- class: 3
# |   |--- capital gain_mmnorm >  0.11
# |   |   |--- capital gain_mmnorm <= 0.71
# |   |   |   |--- class: 2
# |   |   |--- capital gain_mmnorm >  0.71
# |   |   |   |--- class: 1

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': covid_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                   feature  importance
# 11    capital gain_mmnorm         1.0
# 0             workclass_y         0.0
# 1        marital status_y         0.0
# 2            occupation_y         0.0
# 3          relationship_y         0.0
# 4                  race_y         0.0
# 5                gender_y         0.0
# 6             education_y         0.0
# 7       educational num_y         0.0
# 8        native country_y         0.0
# 9                income_y         0.0
# 10             age_mmnorm         0.0
# 12    capital loss_mmnorm         0.0
# 13  hours per week_mmnorm         0.0

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(covid_inputs_train); dtc_model_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(covid_inputs_test); dtc_predict
# Out:
# array([0, 0, 0, ..., 3, 0, 0], dtype=int64)

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(covid_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(covid_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36404
#            1       1.00      1.00      1.00       195
#            2       1.00      1.00      1.00       639
#            3       1.00      1.00      1.00      1835
#
#     accuracy                           1.00     39073
#    macro avg       1.00      1.00      1.00     39073
# weighted avg       1.00      1.00      1.00     39073

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=covid_inputs_names, class_names=covid_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(covid_inputs_train)
dtc_predict_test = dtc_model.predict(covid_inputs_test)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(covid_output_train, dtc_predict_train)
accuracy_dtc_test = accuracy_score(covid_output_test, dtc_predict_test)


# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 372.95703125
# Time taken (seconds): 0.0
# Decision Tree Training Accuracy: 1.0
# Decision Tree Testing Accuracy: 1.0

# %% [markdown]
# # KNN

# %%
# Specify the number of neighbors (k)
k = 5

# Initialize KNN classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Fit the KNN model using the training data
knn.fit(covid_inputs_train, covid_output_train)
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions using the testing data
y_pred = knn.predict(covid_inputs_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.9424710819940628
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      9101
#            1       0.95      0.43      0.59        49
#            2       0.78      0.29      0.42       160
#            3       0.64      0.12      0.20       459
#
#     accuracy                           0.94      9769
#    macro avg       0.83      0.46      0.55      9769
# weighted avg       0.93      0.94      0.92      9769
#
# Confusion Matrix:
# [[9086    1    3   11]
#  [  17   21    9    2]
#  [  97    0   46   17]
#  [ 404    0    1   54]]

# %%
k_values = [9, 11, 13, 15, 17]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(covid_inputs_train, covid_output_train)  # Use your training data here
    y_pred = knn.predict(covid_inputs_test)  # Use your testing data here
    accuracy = accuracy_score(covid_output_test, y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=9: 0.9388883201965401
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 0.9378646739686765
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=13: 0.9370457569863855
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=15: 0.9362268400040946
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=17: 0.9360221107585218

# %%
# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(covid_output_test, y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Specify the number of neighbors (k)
k_values = [9, 11, 13, 15,17]

for k in k_values:
    # Initialize KNN classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)

    # Start time
    start_time = time.time()

    # Fit the KNN model using the training data
    knn.fit(covid_inputs_train, covid_output_train)

    # End time
    end_time = time.time()

    # Time taken for training
    training_time = end_time - start_time

    # Make predictions using the testing data
    y_pred = knn.predict(covid_inputs_test)

    # Calculate accuracy
    accuracy = accuracy_score(covid_output_test, y_pred)

    # Generate classification report
    classification_rep = classification_report(covid_output_test, y_pred)

    # Generate confusion matrix
    conf_mat = confusion_matrix(covid_output_test, y_pred)

    # Memory usage
    memory_used = memory_usage()

    print(f'\nResults for k={k}:')
    print(f'Training Time (seconds): {training_time}')
    print(f'Accuracy: {accuracy}')
    print(f'Classification Report:\n{classification_rep}')
    print(f'Confusion Matrix:\n{conf_mat}')
    print(f'Memory Used (MB): {memory_used}')

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(covid_output_test, y_pred)

from sklearn.model_selection import cross_val_score

# Define the KNN classifier with a chosen number of neighbors (k)
knn = KNeighborsClassifier(n_neighbors=13)  # Example value, you can adjust this

# Perform cross-validation with 20 folds
cv_scores = cross_val_score(knn, covid_inputs, covid_output.values.ravel(), cv=20)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)

# Calculate and print the average accuracy
avg_accuracy = cv_scores.mean()
print("Average Accuracy:", avg_accuracy)
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=9:
# Training Time (seconds): 0.08106708526611328
# Accuracy: 0.9388883201965401
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      9101
#            1       1.00      0.37      0.54        49
#            2       0.84      0.17      0.28       160
#            3       0.54      0.06      0.11       459
#
#     accuracy                           0.94      9769
#    macro avg       0.83      0.40      0.48      9769
# weighted avg       0.92      0.94      0.92      9769
#
# Confusion Matrix:
# [[9098    0    0    3]
#  [  22   18    5    4]
#  [ 115    0   27   18]
#  [ 430    0    0   29]]
# Memory Used (MB): 386.6796875
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=11:
# Training Time (seconds): 0.07594966888427734
# Accuracy: 0.9378646739686765
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      9101
#            1       1.00      0.35      0.52        49
#            2       0.79      0.17      0.28       160
#            3       0.49      0.05      0.08       459
#
#     accuracy                           0.94      9769
#    macro avg       0.81      0.39      0.46      9769
# weighted avg       0.92      0.94      0.91      9769
#
# Confusion Matrix:
# [[9097    0    2    2]
#  [  22   17    5    5]
#  [ 118    0   27   15]
#  [ 438    0    0   21]]
# Memory Used (MB): 386.9765625
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=13:
# Training Time (seconds): 0.07952284812927246
# Accuracy: 0.9370457569863855
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      9101
#            1       1.00      0.27      0.42        49
#            2       0.70      0.16      0.26       160
#            3       0.47      0.04      0.07       459
#
#     accuracy                           0.94      9769
#    macro avg       0.78      0.37      0.43      9769
# weighted avg       0.91      0.94      0.91      9769
#
# Confusion Matrix:
# [[9097    0    2    2]
#  [  23   13    9    4]
#  [ 120    0   26   14]
#  [ 441    0    0   18]]
# Memory Used (MB): 387.2734375
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=15:
# Training Time (seconds): 0.08278250694274902
# Accuracy: 0.9362268400040946
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      9101
#            1       1.00      0.18      0.31        49
#            2       0.63      0.14      0.23       160
#            3       0.44      0.03      0.06       459
#
#     accuracy                           0.94      9769
#    macro avg       0.75      0.34      0.39      9769
# weighted avg       0.91      0.94      0.91      9769
#
# Confusion Matrix:
# [[9099    0    0    2]
#  [  23    9   13    4]
#  [ 124    0   22   14]
#  [ 443    0    0   16]]
# Memory Used (MB): 385.98046875
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=17:
# Training Time (seconds): 0.07425355911254883
# Accuracy: 0.9360221107585218
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      9101
#            1       1.00      0.18      0.31        49
#            2       0.64      0.14      0.23       160
#            3       0.42      0.02      0.05       459
#
#     accuracy                           0.94      9769
#    macro avg       0.75      0.34      0.39      9769
# weighted avg       0.91      0.94      0.91      9769
#
# Confusion Matrix:
# [[9101    0    0    0]
#  [  23    9   13    4]
#  [ 126    0   23   11]
#  [ 448    0    0   11]]
# Memory Used (MB): 385.98046875
# Cross-Validation Scores: [0.93941875 0.93655342 0.93857494 0.93775594 0.93857494 0.93570844
#  0.93734644 0.93898444 0.93898444 0.93529894 0.93775594 0.93693694
#  0.93980344 0.93898444 0.93652744 0.93570844 0.93734644 0.94062244
#  0.93816544 0.93652744]
# Average Accuracy: 0.9377789522488664

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45038, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=45038, solver='liblinear')

# %%
# Make predictions using the trained model
y_pred = logreg.predict(covid_inputs_test)

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.9407308834066946
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      9101
#            1       1.00      0.98      0.99        49
#            2       0.79      0.14      0.24       160
#            3       0.12      0.04      0.06       459
#
#     accuracy                           0.94      9769
#    macro avg       0.72      0.54      0.57      9769
# weighted avg       0.91      0.94      0.92      9769
#
# Confusion Matrix:
# [[9101    0    0    0]
#  [   0   48    1    0]
#  [   0    0   23  137]
#  [ 436    0    5   18]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45047, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = logreg.predict(covid_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 0.5980775356292725
# Time taken for prediction (seconds): 0.0028891563415527344
# Accuracy: 0.9407308834066946
# Memory used (MB): 385.94921875
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      9101
#            1       1.00      0.98      0.99        49
#            2       0.79      0.14      0.24       160
#            3       0.12      0.04      0.06       459
#
#     accuracy                           0.94      9769
#    macro avg       0.72      0.54      0.57      9769
# weighted avg       0.91      0.94      0.92      9769
#
# Confusion Matrix:
# [[9101    0    0    0]
#  [   0   48    1    0]
#  [   0    0   23  137]
#  [ 436    0    5   18]]

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit an SVM classifier with RBF kernel
svm_classifier = SVC(kernel='rbf', random_state=45047)
svm_classifier.fit(covid_inputs_train, covid_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = svm_classifier.predict(covid_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(covid_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(covid_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(covid_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 10.954762935638428
# Time taken for prediction (seconds): 4.155303478240967
# Accuracy: 0.9316204319787081
# Memory used (MB): 386.109375
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      9101
#            1       0.00      0.00      0.00        49
#            2       0.00      0.00      0.00       160
#            3       0.00      0.00      0.00       459
#
#     accuracy                           0.93      9769
#    macro avg       0.23      0.25      0.24      9769
# weighted avg       0.87      0.93      0.90      9769
#
# Confusion Matrix:
# [[9101    0    0    0]
#  [  49    0    0    0]
#  [ 160    0    0    0]
#  [ 459    0    0    0]]
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import time
import psutil
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
covid_inputs_train, covid_inputs_test, covid_output_train, covid_output_test = train_test_split(covid_inputs, covid_output, test_size=0.2, random_state=42)

# Results storage
results = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(covid_inputs_train, covid_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(covid_inputs_test)
dt_accuracy = accuracy_score(covid_output_test, dt_pred)
results.append({'Model': 'Decision Tree', 'Time Taken (s)': dt_training_time, 'Memory Used (MB)': dt_memory_used, 'Accuracy': dt_accuracy})

# KNN
k_values = [5, 7, 9, 11, 13, 15]
for k in k_values:
    knn_start_time = time.time()
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(covid_inputs_train, covid_output_train)
    knn_training_time = time.time() - knn_start_time
    knn_memory_used = memory_usage()
    knn_pred = knn.predict(covid_inputs_test)
    knn_accuracy = accuracy_score(covid_output_test, knn_pred)
    results.append({'Model': f'KNN (k={k})', 'Time Taken (s)': knn_training_time, 'Memory Used (MB)': knn_memory_used, 'Accuracy': knn_accuracy})

# Logistic Regression
lr_start_time = time.time()
logreg = LogisticRegression(random_state=45047, solver='liblinear')
logreg.fit(covid_inputs_train, covid_output_train)
lr_training_time = time.time() - lr_start_time
lr_memory_used = memory_usage()
lr_pred = logreg.predict(covid_inputs_test)
lr_accuracy = accuracy_score(covid_output_test, lr_pred)
results.append({'Model': 'Logistic Regression', 'Time Taken (s)': lr_training_time, 'Memory Used (MB)': lr_memory_used, 'Accuracy': lr_accuracy})

# SVM
svm_start_time = time.time()
svm_classifier = SVC(kernel='rbf', random_state=45047)
svm_classifier.fit(covid_inputs_train, covid_output_train)
svm_training_time = time.time() - svm_start_time
svm_memory_used = memory_usage()
svm_pred = svm_classifier.predict(covid_inputs_test)
svm_accuracy = accuracy_score(covid_output_test, svm_pred)
results.append({'Model': 'SVM', 'Time Taken (s)': svm_training_time, 'Memory Used (MB)': svm_memory_used, 'Accuracy': svm_accuracy})

# Create DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)
# Out:
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\parth\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                  Model  Time Taken (s)  Memory Used (MB)  Accuracy
# 0        Decision Tree        0.032009        388.277344  1.000000
# 1            KNN (k=5)        0.128112        393.410156  0.941652
# 2            KNN (k=7)        0.152575        394.242188  0.939093
# 3            KNN (k=9)        0.128172        395.613281  0.937967
# 4           KNN (k=11)        0.124535        397.058594  0.936227
# 5           KNN (k=13)        0.140384        399.914062  0.934794
# 6           KNN (k=15)        0.128313        402.929688  0.934282
# 7  Logistic Regression        0.649505        404.750000  0.938479
# 8                  SVM       12.957664        391.996094  0.929983
